# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import epanet as epa
import epamodule as em
import seaborn as sns
from cjsbot import CjsBot
import time
from scipy import optimize
import os 
from scipy import stats

# %% [markdown]
# # 4 Dimensões [0.001, 0.2]

# %%
links = ["../../networks/c-town/nodes", 
         "../../networks/c-town/links", 
         "../../networks/c-town/rede.inp", 
         "../../networks/c-town/4dim.csv"]

# %%
t = np.array([0.01,0.079,0.115,0.199])

# %%
t.shape
# Out:
# (4,)

# %%
rv = epa.RealValues(links, t)
rv.target_nodes
rv.getRealValue()

# %%
net = epa.Rede(links, rv.groups, t, [0.001,0.2])
# Out:
# Começando simulação

# %%
net.objetivo(net.target)
# Out:
# 6.563322731438818e-28

# %%
pontos = np.random.random((100,4))*0.2 +0.001

# %%
x = []
y = []
for i in range(100):
    try:
        o = optimize.minimize(net.objetivo, pontos[i,:], method='Nelder-Mead')
        x.append(pontos[i,:])
        y.append(np.round(o.x, decimals=3))
    except:
        continue
CjsBot().send_message("Acabou")
# Out:
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# ...

# %%
d = []
for i in range(len(y)):
    d.append(net.get_dist(x[i]))

# %%
plt.plot(d)

# %%
net.objetivo(y[1])/net.objetivo(net.target)
# Out:
# 2.6266096761815632e+26

# %%
net.gradient(y[1])
# Out:
# array([11.748, -1.622,  6.93 , -1.636])

# %% [markdown]
# # 4 dimensões [0.001, 1]

# %%
links = ["../../networks/c-town/nodes", 
         "../../networks/c-town/links", 
         "../../networks/c-town/rede.inp", 
         "../../networks/c-town/4dimlarge.csv"]

# %%
t = np.array([0.89,0.079,0.115,0.785])

# %%
t.shape
# Out:
# (4,)

# %%
rv = epa.RealValues(links, t)
rv.target_nodes
rv.getRealValue()

# %%
net = epa.Rede(links, rv.groups, t, [0.001,1])
# Out:
# Começando simulação

# %%
net.objetivo(net.target)
# Out:
# 4.543838814073028e-28

# %%
pontos = np.random.random((500,4))*1 + 0.001
pontos
# Out:
# array([[0.53731611, 0.77899111, 0.27870117, 0.69994796],
#        [0.86474969, 0.93630774, 0.07900186, 0.78585529],
#        [0.08762119, 0.58642951, 0.6177735 , 0.05833036],
#        ...,
#        [0.33796348, 0.25491149, 0.90976397, 0.39984536],
#        [0.14776254, 0.21993719, 0.00533628, 0.03319288],
#        [0.54002024, 0.36406251, 0.6439575 , 0.9262208 ]])

# %%
x = []
y = []
for i in range(100):
    try:
        o = optimize.minimize(net.objetivo, pontos[i,:], method='Nelder-Mead')
        x.append(pontos[i,:])
        y.append(np.round(o.x, decimals=3))
        print(np.round(o.x, decimals=3))
    except:
        print("Deu erro")
CjsBot().send_message(f"Acabou\n{len(y)}")
# Out:
# [0.89  0.079 0.115 0.785]
# [0.89  0.079 0.115 0.785]
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# [0.89  0.079 0.115 0.785]
# [0.89  0.079 0.115 0.785]
# [0.89  0.079 0.115 0.785]
# [0.89  0.079 0.115 0.785]
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# [0.89  0.079 0.115 0.785]
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# [0.89  0.079 0.115 0.785]
# [0.89  0.079 0.115 0.785]
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# [0.89  0.079 0.115 0.785]
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# [0.89  0.079 0.115 0.785]
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# [0.89  0.079 0.115 0.785]
# Houve um erro
# Deu erro
# Houve um erro
# Deu erro
# Houve um erro
# ...

# %%
y
# Out:
# [array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785]),
#  array([0.89 , 0.079, 0.115, 0.785])]

# %%
d = []
for i in range(len(y)):
    d.append(net.get_dist(x[i]))

# %%
plt.plot(d)

# %%
pontos = np.random.random((800,4))*1 + 0.001

# %%
x = []
y = []
erro = []
for i in range(100):
    try:
        o = optimize.minimize(net.objetivo, pontos[i,:], method='Nelder-Mead')
        x.append(pontos[i,:])
        y.append(np.round(o.x, decimals=3))
        print(np.round(o.x, decimals=3))
    except:
        erro.append(net.ultimo_ponto)
        continue
CjsBot().send_message(f"Acabou\n{len(y)}")
# Out:
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# [0.01  0.079 0.115 0.5  ]
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# ...

# %%
erro = np.array(erro)

# %%
mean = 0
for i in range(erro.shape[0]):
    mean = (net.get_dist(erro[i,:]))/erro.shape[0]

# %%
mean
# Out:
# 0.009680198180634227

# %%
o = optimize.minimize(net.objetivo, pontos[0,:], method='Nelder-Mead')
# Out:
# [0.02479112 0.29724928 0.18764942 0.52216637]
# [0.02603068 0.29724928 0.18764942 0.52216637]
# [0.02479112 0.31211175 0.18764942 0.52216637]
# [0.02479112 0.29724928 0.19703189 0.52216637]
# [0.02479112 0.29724928 0.18764942 0.54827468]
# [0.0254109  0.30468052 0.17826695 0.53522052]
# [0.02572079 0.30839613 0.16888448 0.5417476 ]
# [0.0240164  0.31025394 0.17826695 0.54501114]
# [0.02486859 0.29446257 0.17357571 0.55643353]
# [0.02490733 0.30793168 0.16653886 0.57356712]
# [0.02496543 0.31327288 0.15598358 0.59926749]
# [0.02499448 0.31594348 0.15070594 0.5729552 ]
# [0.02509617 0.32529057 0.1322342  0.58529546]
# [0.02630909 0.31045714 0.13707204 0.5963609 ]
# [0.02617715 0.33424579 0.12351143 0.6049022 ]
# [0.02683142 0.3541374  0.09847929 0.62913653]
# [0.02588027 0.34318286 0.09300008 0.66328259]
# [0.02709304 0.35326111 0.07440922 0.63777025]
# [0.02614136 0.37747883 0.06198936 0.66138152]
# [0.02626716 0.32721256 0.11830137 0.61261606]
# ...

# %%
np.random.random((15,))*1 +0.001
t = np.array([0.075, 0.812, 0.317, 0.581, 0.752, 0.994, 0.967, 0.511, 0.851,
              0.925, 0.842, 0.295, 0.633, 0.522, 0.306])
bot = CjsBot()
for i in range(5,16):
    links = ["../../networks/c-town/nodes", 
         "../../networks/c-town/links", 
         "../../networks/c-town/rede.inp", 
         f"../../networks/c-town/{i}dim.csv"]
    os.mkdir(f'./teste_nn/{i}')
    tt = t[:i]
    rv = epa.RealValues(links, tt)
    rv.target_nodes
    rv.getRealValue()
    net = epa.Rede(links, rv.groups, tt, [0.001,1])
    x = []
    y = []
    pontos = np.random.random((500,i))*1 +0.01
    for j in range(800):
        try:
            o = optimize.minimize(net.objetivo, pontos[j,:], method='Nelder-Mead')
            x.append(pontos[j,:])
            y.append(np.round(o.x, decimals=3))
        except:
            continue
    d = []
    for j in range(len(y)):
        d.append(net.get_dist(x[j]))
    fig, ax = plt.subplots()
    ax.hist(d)
    plt.ylabel('Contagem')
    plt.xlabel('Distância')
    fig.savefig(f'./teste_nn/{i}/grafico.png', format='png')
    x = np.array(x)
    arq = open(f'./teste_nn/{i}/x.txt','a')
    np.savetxt(arq, x)
    arq.close()
    bot.send_message(f"{15-i}")
bot.send_message("Acabou")
# Out:
# Começando simulação
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# Houve um erro
# ...

# %%
t = np.array([0.075, 0.812, 0.317, 0.581, 0.752, 0.994, 0.967, 0.511, 0.851,
              0.925, 0.842, 0.295, 0.633, 0.522, 0.306])
bot = CjsBot()
for i in range(1,5):
    links = ["../../networks/c-town/nodes", 
         "../../networks/c-town/links", 
         "../../networks/c-town/rede.inp", 
         f"../../networks/c-town/{i}dim.csv"]
    if not os.path.isdir(f'./teste_nn/{i}'):
        os.mkdir(f'./teste_nn/{i}')
    tt = t[:i]
    rv = epa.RealValues(links, tt)
    rv.getRealValue()
    net = epa.Rede(links, rv.groups, tt, [0.001,1])
    #arq = open(f'./teste_nn/{i}/x.txt')
    x = []
    y = []
    pontos = np.random.random((500,i))*1 +0.001
    for j in range(pontos.shape[0]):
        try:
            o = optimize.minimize(net.objetivo, pontos[j,:], method='Nelder-Mead')
            x.append(pontos[j,:])
            y.append(np.round(o.x, decimals=3))
            print(y[-1])
        except:
            continue
    
    arq = open(f'./teste_nn/{i}/y.txt','a')
    np.savetxt(arq, y)
    arq.close()
    arq = open(f'./teste_nn/{i}/x.txt','a')
    np.savetxt(arq, x)
    arq.close()
    bot.send_message(f"Estou na dimensão {i}")
    
bot.send_message("Acabou")
# Out:
# Começando simulação
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# [0.075]
# Começando simulação
# [0.075 0.812]
# [0.075 0.812]
# [0.075 0.812]
# ...

# %%
# Fazer um gráfico boxplot dimensões x distância
# Verificar a moda dos resultado, ver se muda ao longo das dims
# Começando com uma dimensão
# Fazer os mesmos 500 para todas dimensões variando os conjuntos
# Variar conjuntos com uma 'seed' específica ( verificar se ele gera os mesmo 500 com a mesma seed)
# Colocar fixo a quantidade de nós para todas dim+ (com esquema da classe realvalues)
# Pegar os mesmos nós e tentar para todas as dims

# %%
t = np.array([0.075, 0.812, 0.317, 0.581, 0.752, 0.994, 0.967, 0.511, 0.851,
              0.925, 0.842, 0.295, 0.633, 0.522, 0.306])
for i in range(2,16):
    links = ["../../networks/c-town/nodes", 
         "../../networks/c-town/links", 
         "../../networks/c-town/rede.inp", 
         f"../../networks/c-town/{i}dim.csv"]
    tt = t[:i]
    rv = epa.RealValues(links, tt)
    rv.getRealValue()
    net = epa.Rede(links, rv.groups, tt, [0.001,1])
    arq = open(f'./teste_nn/{i}/y.txt')
    y = np.loadtxt(arq)
    y = np.round(y, decimals=3)
    # Calcular moda, desvio padrão e fazer boxplot para cada dimensão
    s = open(f'./teste_nn/{i}/stats.txt', 'a')
    dists = []
    print(y.shape)
    for j in range(y.shape[0]):
        dists.append(net.get_dist(y[j,:]))
    dists = np.array(dists)
    s.write(f'mode:{stats.mode(dists)}\nsd:{dists.std()}')
    s.close
    arq = open(f'./teste_nn/{i}/dists.txt', 'a')
    np.savetxt(arq, dists)
    
    fig, ax = plt.subplots()
    ax.boxplot(dists, vert=False,)
    plt.xlabel('Distância')
    fig.savefig(f'./teste_nn/{i}/boxplot_dists.png', format='png')
    
bot.send_message("Acabou")
# Out:
# Começando simulação
# (543, 2)
# Começando simulação
# (118, 3)
# Começando simulação
# (148, 4)
# Começando simulação
# (111, 5)
# Começando simulação
# (130, 6)
# Começando simulação
# (75, 7)
# Começando simulação
# (44, 8)
# Começando simulação
# (28, 9)
# Começando simulação
# (68, 10)
# Começando simulação
# (43, 11)
# Começando simulação
# (19, 12)
# Começando simulação
# (43, 13)
# Começando simulação
# (16, 14)
# Começando simulação
# (10, 15)

# %%
t = np.array([0.075, 0.812, 0.317, 0.581, 0.752, 0.994, 0.967, 0.511, 0.851,
              0.925, 0.842, 0.295, 0.633, 0.522, 0.306])
sd = []
for i in range(2,16):
    arq = open(f'./teste_nn/{i}/stats.txt').read()
    s = [e for e in arq.split('\n')] 
    sd.append(float(s[1].split(':')[1]))
    
    
fig, ax = plt.subplots()
ax.plot(np.linspace(2,15,14), sd)
plt.xlabel('Dimensão')
plt.ylabel("Desvio padrão")
fig.savefig(f'./teste_nn/dim_sd.png', format='png')
# Out:
# mode:ModeResult(mode=array([0.]), count=array([543]))
# sd:0.0
# mode:ModeResult(mode=array([0.]), count=array([110]))
# sd:0.13678152222311946
# mode:ModeResult(mode=array([0.]), count=array([145]))
# sd:0.08850679271622428
# mode:ModeResult(mode=array([0.]), count=array([102]))
# sd:0.10570967394595981
# mode:ModeResult(mode=array([0.9132141]), count=array([2]))
# sd:0.5391347624714091
# mode:ModeResult(mode=array([0.02893095]), count=array([1]))
# sd:1.0378003807103793
# mode:ModeResult(mode=array([0.]), count=array([1]))
# sd:0.6697040229265203
# mode:ModeResult(mode=array([0.02580698]), count=array([1]))
# sd:0.3205741113053996
# mode:ModeResult(mode=array([0.14211967]), count=array([1]))
# sd:1.733819284044943
# mode:ModeResult(mode=array([0.02840775]), count=array([1]))
# sd:0.7124481577333382
# mode:ModeResult(mode=array([0.73554538]), count=array([1]))
# sd:0.2959206599206734
# mode:ModeResult(mode=array([0.47329378]), count=array([1]))
# sd:0.6872488620117945
# ...

# %%
s[1].split(':')[1]
# Out:
# '0.0'

# %%
np.random.seed(48)
np.random.random(3)
# Out:
# array([0.01749027, 0.89157327, 0.28486117])

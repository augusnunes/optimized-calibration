# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns

# %%
seeds = [661, 308, 769, 343, 491]
posicao_nos = [0.1,0.3,0.5,0.7,0.9]
q_nos = [10,20,30,40,50]

# %%
arq = open("dados.csv", 'a')

# %%
arq.write("seed,posicao_no,quantidade_nos,dimensao,moda,n_moda,std,count\n")
# Out:
# 62

# %%
a = np.random.random((100,))

# %%
stats.mode([1,1,1]).count[0]
# Out:
# 3

# %%
a.std()
# Out:
# 0.2954747729292122

# %%
for seed in seeds:
    for p_n in posicao_nos:
        for q_n in q_nos:
            for dim in range(1,16):
                v = np.loadtxt(open(f"{seed}/{p_n}/{q_n}/{dim}/dists.txt"))
                arq.write(f"{seed},{p_n},{q_n},{dim},{stats.mode(v).mode[0]},{stats.mode(v).count[0]},{v.std()},{v.shape[0]}\n")

# %%
arq.close()

# %%
arq = open("dados2.csv", 'a')
arq.write("seed,posicao_no,quantidade_nos,dimensao,moda,n_moda,std,count,tipo,n\n")
for seed in seeds:
    for p_n in posicao_nos:
        for q_n in q_nos:
            for dim in range(1,16):
                v = np.loadtxt(open(f"{seed}/{p_n}/{q_n}/{dim}/dists.txt"))
                a = f"{seed},{p_n},{q_n},{dim},{stats.mode(v).mode[0]},{stats.mode(v).count[0]},{v.std()},{v.shape[0]},pontos totais,{v.shape[0]}\n"
                b = f"{seed},{p_n},{q_n},{dim},{stats.mode(v).mode[0]},{stats.mode(v).count[0]},{v.std()},{v.shape[0]},pontos na moda,{stats.mode(v).count[0]}\n"               
                arq.write(a)
                arq.write(b)
arq.close()

# %%
df = pd.read_csv("dados.csv")

# %%
df
# Out:
#       seed  posicao_no  quantidade_nos  dimensao      moda  n_moda       std  \
# 0      661         0.1              10         1  0.000000      88  0.000000
# 1      661         0.1              10         2  0.000000     276  0.000000
# 2      661         0.1              10         3  0.000000     158  0.000000
# 3      661         0.1              10         4  0.000000     116  0.000092
# 4      661         0.1              10         5  0.000000     186  0.109048
# ...    ...         ...             ...       ...       ...     ...       ...
# 1870   491         0.9              50        11  0.000000      19  0.549083
# 1871   491         0.9              50        12  0.072353       1  1.006339
# 1872   491         0.9              50        13  0.019183       1  0.619816
# 1873   491         0.9              50        14  0.026476       1  0.464791
# 1874   491         0.9              50        15  0.214047       1  0.635389
#
#       count
# 0        88
# 1       276
# ...

# %%
sns.lineplot(x="dimensao", y="n_moda", data=df)
sns.lineplot(x="dimensao", y="count", data=df)
# Out:
# <AxesSubplot:xlabel='dimensao', ylabel='n_moda'>

# %%
sns.lineplot(x="dimensao", y="n_moda", data=df)
# Out:
# <AxesSubplot:xlabel='dimensao', ylabel='n_moda'>

# %%
df.columns
# Out:
# Index(['seed', 'posicao_no', 'quantidade_nos', 'dimensao', 'moda', 'n_moda',
#        'std', 'count'],
#       dtype='object')

# %%
df = pd.read_csv("dados2.csv")

# %%
g = sns.FacetGrid(df[df.seed == 769], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="n")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-336352137cc4> in <module>
#       3 g.set_axis_labels("Dimensão", "Counts")
#       4 g.add_legend()
# ----> 5 g.save_fig("grafico.png")
#
# AttributeError: 'FacetGrid' object has no attribute 'save_fig'

# %%
g.savefig("grafico.png")

# %%
g = sns.FacetGrid(df[df.seed == 661], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="n")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()

# %%
g = sns.FacetGrid(df[df.seed == 308], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="n")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()

# %%
g = sns.FacetGrid(df[df.seed == 343], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="n")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()

# %%
m
# Out:
# array([[6.61000000e+02, 1.00000000e-01, 1.00000000e+01, 8.00000000e+00,
#         1.63401346e-02],
#        [6.61000000e+02, 1.00000000e-01, 2.00000000e+01, 1.20000000e+01,
#         2.99666481e-02],
#        [6.61000000e+02, 1.00000000e-01, 3.00000000e+01, 1.10000000e+01,
#         2.00000000e-03],
#        [6.61000000e+02, 1.00000000e-01, 4.00000000e+01, 1.20000000e+01,
#         2.46779254e-02],
#        [6.61000000e+02, 1.00000000e-01, 5.00000000e+01, 1.10000000e+01,
#         2.00000000e-03],
#        [6.61000000e+02, 3.00000000e-01, 1.00000000e+01, 9.00000000e+00,
#         7.07106781e-03],
#        [6.61000000e+02, 3.00000000e-01, 2.00000000e+01, 1.00000000e+01,
#         1.00498756e-02],
#        [6.61000000e+02, 3.00000000e-01, 3.00000000e+01, 1.20000000e+01,
#         1.06174385e-01],
#        [6.61000000e+02, 3.00000000e-01, 4.00000000e+01, 1.20000000e+01,
#         3.02489669e-02],
#        [6.61000000e+02, 3.00000000e-01, 5.00000000e+01, 1.20000000e+01,
# ...

# %%
(df[(df.seed == 661) & (df.posicao_no == 0.1) & (df.quantidade_nos==10) & (df.dimensao == 15)].moda != 0).values[0]
# Out:
# True

# %%
seeds
# Out:
# [661, 308, 769, 343, 491]

# %%
df[(df.seed == seed) & (df.posicao_no == posicao_no) & (df.quantidade_nos==q_no) & (df.dimensao == dim)].moda.values
# Out:
# array([0.21404672])

# %%
moda_diferent0 = []
for seed in seeds:
    for posicao_no in posicao_nos:
        for q_no in q_nos:
            for dim in range(1,16):
                if (df[(df.seed == seed) & (df.posicao_no == posicao_no) & (df.quantidade_nos==q_no) & (df.dimensao == dim)].moda != 0).values[0]:                  
                    v = df[(df.seed == seed) & (df.posicao_no == posicao_no) & (df.quantidade_nos==q_no) & (df.dimensao == dim)].moda.values[0]
                    moda_diferent0.append([seed, posicao_no, q_no, dim, v])
                    break

# %%
moda_diferent0 = np.array(moda_diferent0)

# %%
m = moda_diferent0[:5*5,:]

# %%
import plotly.graph_objects as go

# %% [markdown]
# # Dimensão em que a moda começa a dar != 0

# %%
print(f"seed {seeds[0]}")
m = moda_diferent0[:5*5,:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,m[:, -2].reshape(5,5) ])))])
fig.show()
# Out:
# seed 661
# ...

# %%
c = 1
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,m[:, -2].reshape(5,5) ])))])
fig.show()
# Out:
# seed 308
# ...

# %%
c = 2
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,m[:, -2].reshape(5,5) ])))])
fig.show()
# Out:
# seed 769
# ...

# %%
c = 3
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,m[:, -2].reshape(5,5) ])))])
fig.show()
# Out:
# seed 343
# ...

# %%
c = 4
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,m[:, -2].reshape(5,5) ])))])
fig.show()
# Out:
# seed 491
# ...

# %% [markdown]
# # O primeiro valor diferente de 0 da moda

# %%
c = 0
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,np.round(m[:, -1].reshape(5,5), decimals=3) ])))])
fig.show()
# Out:
# seed 661
# ...

# %%
c = 1
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,np.round(m[:, -1].reshape(5,5), decimals=3) ])))])
fig.show()
# Out:
# seed 308
# ...

# %%
c = 2
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,np.round(m[:, -1].reshape(5,5), decimals=3) ])))])
fig.show()
# Out:
# seed 769
# ...

# %%
c = 3
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,np.round(m[:, -1].reshape(5,5), decimals=3) ])))])
fig.show()
# Out:
# seed 343
# ...

# %%
c = 4
print(f"seed {seeds[c]}")
m = moda_diferent0[c*5*5:5*5*(c+1),:]
fig = go.Figure(data=[go.Table(header=dict(values=['posicao_nos','10 nós', '20 nós', '30 nós', '40 nós', '50 nós']),
                 cells=dict(values=np.vstack([posicao_nos,np.round(m[:, -1].reshape(5,5), decimals=3) ])))])
fig.show()
# Out:
# seed 491
# ...

# %% [markdown]
# # Fazendo com a moda valendo 0

# %%
arq = open("dados3.csv", 'a')
print('Para fazer o gráfico da distância 0')
arq.write("seed,posicao_no,quantidade_nos,dimensao,count,tipo\n")
for seed in seeds:
    for p_n in posicao_nos:
        for q_n in q_nos:
            for dim in range(1,16):
                v = np.loadtxt(open(f"{seed}/{p_n}/{q_n}/{dim}/dists.txt"))
                unique, counts = np.unique(v, return_counts=True)
                estat = dict(zip(unique, counts))
                if 0.0 in estat:
                    dist0 = estat[0.0]
                else:
                    dist0 = 0
                a = f"{seed},{p_n},{q_n},{dim},{dist0},ponto alvo\n"
                b = f"{seed},{p_n},{q_n},{dim},{v.shape[0]},pontos totais\n"
                arq.write(a)
                arq.write(b)
arq.close()
# Out:
# Para fazer o gráfico da distância 0

# %%
df = pd.read_csv("dados3.csv")
df.seed.value_counts()
# Out:
# 769    750
# 661    750
# 491    750
# 343    750
# 308    750
# Name: seed, dtype: int64

# %%
c = seeds[0]
g = sns.FacetGrid(df[df.seed == c], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="count")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()
g.savefig(f"dist0_{c}.png")

# %%
c = seeds[1]
g = sns.FacetGrid(df[df.seed == c], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="count")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()
g.savefig(f"dist0_{c}.png")

# %%
c = seeds[2]
g = sns.FacetGrid(df[df.seed == c], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="count")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()
g.savefig(f"dist0_{c}.png")

# %%
c = seeds[3]
g = sns.FacetGrid(df[df.seed == c], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="count")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()
g.savefig(f"dist0_{c}.png")

# %%
c = seeds[4]
g = sns.FacetGrid(df[df.seed == c], col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="count")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()
g.savefig(f"dist0_{c}.png")

# %%
g = sns.FacetGrid(df, col="quantidade_nos",  row="posicao_no", hue="tipo")
g.map_dataframe(sns.lineplot, x="dimensao", y="count")
g.set_axis_labels("Dimensão", "Counts")
g.add_legend()
g.savefig(f"dist0_total.png")

# %% [markdown]
# # Média

# %%
arq = open("dados4.csv", 'a')
print('média e desvio padrão')
arq.write("seed,posicao_no,quantidade_nos,dimensao,media,std\n")
for seed in seeds:
    for p_n in posicao_nos:
        for q_n in q_nos:
            for dim in range(1,16):
                v = np.loadtxt(open(f"{seed}/{p_n}/{q_n}/{dim}/dists.txt"))
                a = f"{seed},{p_n},{q_n},{dim},{v.mean()}, {v.std()}\n"
                arq.write(a)
arq.close()
# Out:
# Para fazer o gráfico da distância 0

# %%
df = pd.read_csv('dados4.csv')
for i in range(5):
    c = seeds[i]
    g = sns.FacetGrid(df[df.seed == c], col="quantidade_nos",  row="posicao_no")
    g.map_dataframe(sns.lineplot, x="dimensao", y="media")
    g.set_axis_labels("Dimensão", "Média")
    g.add_legend()
    g.savefig(f"media_{c}.png")

# %%
for i in range(5):
    c = seeds[i]
    g = sns.FacetGrid(df[df.seed == c], col="quantidade_nos",  row="posicao_no")
    g.map_dataframe(sns.lineplot, x="dimensao", y="std")
    g.set_axis_labels("Dimensão", "Desvio Padrão")
    g.add_legend()
    g.savefig(f"std_{c}.png")
